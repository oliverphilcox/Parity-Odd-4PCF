# %%
# %pylab inline
from classy import Class
from scipy.interpolate import interp1d
from scipy.integrate import simps
from scipy.special import spherical_jn, sici
from sympy.physics.wigner import wigner_3j, wigner_6j, wigner_9j

# Parameters
z = 0.57
h = 0.68
R_min = 20
R_max = 160
n_r = 10
LMAX = 4
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['indices']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
### Load matter power spectrum (for testing)
print("NEED TO ADD PROPER POWER SPECTRUM!")
cosmo = Class()
cosmo.set({'output':'mPk,mTk,tCl','z_pk':z,'h':h,'P_k_max_1/Mpc':100.0})
cosmo.compute()

k_arr = np.logspace(-4,2,10000)
pk_lin_arr = np.asarray([cosmo.pk_lin(kk*h,z)*h**3. for kk in k_arr])

b = 2.0
fz = cosmo.scale_independent_growth_factor_f(z)

# Load transfer functions
T_all = cosmo.get_transfer(z,'class')
kTk = T_all['k (h/Mpc)']
Tk = T_all['d_tot']
Tk_arr = interp1d(kTk,Tk)(k_arr)

# Compute interpolator for curvature power spectrum and transfer function
p_zeta = interp1d(k_arr,pk_lin_arr/Tk_arr**2.)
M = interp1d(k_arr,Tk_arr)
# Out:
# NEED TO ADD PROPER POWER SPECTRUM!

# %%
x_arr = np.arange(0,250,0.5)
xp_arr = np.arange(0,251,0.5)
k_arr = np.arange(0.001,3,0.01)[:,None]

# Define bin-integrated Bessel functions
def integ_bessel(ell,bin1,k):
    r_min = bin1*(R_max-R_min)/n_r+R_min
    r_max = (bin1+1.)*(R_max-R_min)/n_r+R_min
    if ell==0:
        tmp1 = (-k*r_max*np.cos(k*r_max)+np.sin(k*r_max))/k**3. 
        tmp2 = (-k*r_min*np.cos(k*r_min)+np.sin(k*r_min))/k**3.
    elif ell==1:
        tmp1 = -2.*np.cos(k*r_max)/k**3. - r_max*np.sin(k*r_max)/k**2.
        tmp2 = -2.*np.cos(k*r_min)/k**3. - r_min*np.sin(k*r_min)/k**2.
    elif ell==2:
        tmp1 = (r_max*np.cos(k*r_max))/k**2 - (4*np.sin(k*r_max))/k**3 + (3*sici(k*r_max)[0])/k**3
        tmp2 = (r_min*np.cos(k*r_min))/k**2 - (4*np.sin(k*r_min))/k**3 + (3*sici(k*r_min)[0])/k**3
    elif ell==3:
        tmp1 = (7.*np.cos(k*r_max))/k**3 - (15.*np.sin(k*r_max))/(k**4*r_max) + (r_max*np.sin(k*r_max))/k**2
        # avoid zero errors!
        if r_min==0:
            tmp2 = -(8./k**3.)
        else:
            tmp2 = (7.*np.cos(k*r_min))/k**3 - (15.*np.sin(k*r_min))/(k**4*r_min) + (r_min*np.sin(k*r_min))/k**2
    elif ell==4:
        tmp1 = (105.*np.cos(k*r_max))/(2.*k**4*r_max) - (r_max*np.cos(k*r_max))/k**2 + (11*np.sin(k*r_max))/k**3 -(105*np.sin(k*r_max))/(2.*k**5*r_max**2) + (15*sici(k*r_max)[0])/(2.*k**3)
        if r_min==0:
            tmp2 = 0.
        else:
            tmp2 = (105.*np.cos(k*r_min))/(2.*k**4*r_min) - (r_min*np.cos(k*r_min))/k**2 + (11*np.sin(k*r_min))/k**3 -(105*np.sin(k*r_min))/(2.*k**5*r_min**2) + (15*sici(k*r_min)[0])/(2.*k**3)
    elif ell==5:
        tmp1 = ((315*k*r_max - 16*k**3*r_max**3)*np.cos(k*r_max) - (315 - 105*k**2*r_max**2 + k**4*r_max**4)*np.sin(k*r_max))/(k**6*r_max**3)
        if r_min==0:
            tmp2 = -16./k**3.
        else:
            tmp2 = ((315*k*r_min - 16*k**3*r_min**3)*np.cos(k*r_min) - (315 - 105*k**2*r_min**2 + k**4*r_min**4)*np.sin(k*r_min))/(k**6*r_min**3)
    else:
        raise Exception("not implemented yet!")
    return (tmp1-tmp2)/((r_max**3.-r_min**3.)/3.)

# Compute j_l(kx) possibilities
jl_kx = []
print("Computing j_ell(kx)")
for l in range(LMAX+1):
    jl_kx.append(spherical_jn(l,k_arr*x_arr))

# Compute j_l(kx) possibilities
jl_kxp = []
print("Computing j_ell(kx')")
for l in range(LMAX+1):
    jl_kxp.append(spherical_jn(l,k_arr*xp_arr))
    
# Compute j_ell(kr) possibilities
# add one extra row for the r = 0 case!
jell_kr = []
print("Computing j_ell(kr)")
for ell in range(LMAX+1):
    tmp_jell_kr = []
    for rbin in range(n_r):
        tmp_jell_kr.append(integ_bessel(ell,rbin,k_arr))
    tmp_jell_kr.append(np.ones_like(integ_bessel(ell,rbin,k_arr)))
    jell_kr.append(tmp_jell_kr)
    
tj0 = lambda l1,l2,l3: np.float64(wigner_3j(l1,l2,l3,0,0,0))
# Out:
# Computing j_ell(kx)
# Computing j_ell(kx')
# Computing j_ell(kr)

# %% [markdown]
# ### Compute the k1 - k4 integrals

# %%
Mk = M(k_arr)
pk_zeta = p_zeta(k_arr)
k2_norm = k_arr**2./(2.*np.pi**2.)
x2 = (x_arr**2.)[:,None]
x2p = xp_arr**2.

def Pk1(L, lH, bH):
    return simps(k2_norm*Mk*pk_zeta*jell_kr[lH][bH]*jl_kx[L],k_arr,axis=0)

def Pk2(L, lH, bH):
    return simps(k2_norm*Mk*jell_kr[lH][bH]*jl_kx[L],k_arr,axis=0)

def Pk3(L, lH, bH):
    return simps(k2_norm*Mk*pk_zeta*jell_kr[lH][bH]*jl_kxp[L],k_arr,axis=0)

def Pk4(L, lH, bH):
    return simps(k2_norm*Mk*jell_kr[lH][bH]*jl_kxp[L],k_arr,axis=0)

def Ps(L1, L2):
    return simps(k2_norm[:,None]*pk_zeta[:,None]*jl_kx[L1][:,:,None]*jl_kxp[L2][:,None,:],k_arr[:,None],axis=0)

# %%
Ps_arr = []
for L1 in range(LMAX+1):
    print(L1)
    Ps1 = []
    for L2 in range(LMAX+1):
        Ps1.append(Ps(L1,L2))
    Ps_arr.append(Ps1)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
Pk1_arr = []
Pk2_arr = []
Pk3_arr = []
Pk4_arr = []
for L in range(LMAX+1):
    Pk1a,Pk2a,Pk3a,Pk4a = [],[],[],[]
    for l in range(LMAX+1):
        Pk1b,Pk2b,Pk3b,Pk4b = [],[],[],[]
        for b in range(n_r+1):
            Pk1b.append(Pk1(L,l,b))
            Pk2b.append(Pk2(L,l,b))
            Pk3b.append(Pk3(L,l,b))
            Pk4b.append(Pk4(L,l,b))
        Pk1a.append(Pk1b)
        Pk2a.append(Pk2b)
        Pk3a.append(Pk3b)
        Pk4a.append(Pk4b)
    Pk1_arr.append(Pk1a)
    Pk2_arr.append(Pk2a)
    Pk3_arr.append(Pk3a)
    Pk4_arr.append(Pk4a)

# %%
l1,l2,l3 = 1,1,1
b1,b2,b3 = 1,2,3

import itertools
indices=set(itertools.permutations([0,1,2,3]))

for ii,index in enumerate(indices):
    print("Symmetry index %d of %d"%(ii+1,len(indices)))
    
    # Compute permuted ell, bins
    ells = np.asarray([l1,l2,l3,0])
    bins = np.asarray([b1,b2,b3,-1])
    
    ells_perm = ells[list(index)] 
    lH1,lH2,lH3,lH4 = ells_perm
    bH1, bH2, bH3, bH4 = bins[list(index)]
    
    # Compute intermediate ell (already determined)
    if lH1==0: lH12=lH2
    elif lH2==0: lH12 = lH1
    elif lH3==0: lH12 = lH4
    elif lH4==0: lH12 = lH3
    else: raise Exception("wrong ells!")

    # Determine permutation factor
    cnt = 0
    ells_perm = np.delete(ells_perm,np.where(ells_perm==0)[0][0])
    for i in range(3):
        for j in range(i+1,3):
            if (ells_perm[i]>ells_perm[j]):
                cnt+=1
    if cnt%2==0: phiH = 1
    else: phiH = -1
# Out:
# Symmetry index 1 of 24
# Symmetry index 2 of 24
# Symmetry index 3 of 24
# Symmetry index 4 of 24
# Symmetry index 5 of 24
# Symmetry index 6 of 24
# Symmetry index 7 of 24
# Symmetry index 8 of 24
# Symmetry index 9 of 24
# Symmetry index 10 of 24
# Symmetry index 11 of 24
# Symmetry index 12 of 24
# Symmetry index 13 of 24
# Symmetry index 14 of 24
# Symmetry index 15 of 24
# Symmetry index 16 of 24
# Symmetry index 17 of 24
# Symmetry index 18 of 24
# Symmetry index 19 of 24
# Symmetry index 20 of 24
# Symmetry index 21 of 24
# Symmetry index 22 of 24
# Symmetry index 23 of 24
# Symmetry index 24 of 24

# %%
C_ell = lambda Ls: np.sqrt(np.product(2.*np.asarray(L)+1.))

def Z_ell(ell):
    """Compute the Z_ell coefficients"""
    if ell==0: 
        return 4.*np.pi*(b+fz/3.)
    elif ell==2:
        return 4.*np.pi*(2./15.*fz)
    else:
        raise Exception('Wrong ell!')

def Gaunt4(L,Lp,Lpp,wigs=[]):
    """Return G^{L,L',L''} for N=4.
    Indexing is L = {l1,l2,l12,l3,l4}.
    We skip computing Wigner 3j symbols if they are supplied."""
    if len(wigs)!=0:
        wig3s = wigs[0]*wigs[1]*wigs[2]*wigs[3]
    else:
        wig3s = tj0(L[0],Lp[0],Lpp[0]) # l1
        if wig3s==0: return 0.
        wig3s *= tj0(L[1],Lp[1],Lpp[1]) # l2
        if wig3s==0: return 0.
        wig3s *= tj0(L[3],Lp[3],Lpp[3]) # l3
        if wig3s==0: return 0.
        wig3s *= tj0(L[4],Lp[4],Lpp[4]) # l4
        if wig3s==0: return 0.
    wig9s = np.float64(wigner_9j(L[0],L[1],L[2],Lp[0],Lp[1],Lp[2],Lpp[0],Lpp[1],Lpp[2]))
    if wig9s==0: return 0.
    wig9s *= np.float64(wigner_9j(L[2],L[3],L[4],Lp[2],Lp[3],Lp[4],Lpp[2],Lpp[3],Lpp[4]))
    if wig9s==0: return 0.
    pref = C_ell(L)*C_ell(Lp)*C_ell(Lpp)/(4.*np.pi)**2.
    return pref*wig3s*wig9s

def Gaunt5(L,Lp,Lpp,wigs=[]):
    """Return G^{L,L',L''} for N=5.
    Indexing is L = {l1,l2,l12,l3,l123,l4,l5}.
    We skip computing Wigner 3j symbols if they are supplied."""
    if len(wigs)!=0:
        wig3s = wigs[0]*wigs[1]*wigs[2]*wigs[3]*wigs[4]
    else:
        wig3s = tj0(L[0],Lp[0],Lpp[0]) # l1
        if wig3s==0: return 0.
        wig3s *= tj0(L[1],Lp[1],Lpp[1]) # l2
        if wig3s==0: return 0.
        wig3s *= tj0(L[3],Lp[3],Lpp[3]) # l3
        if wig3s==0: return 0.
        wig3s *= tj0(L[5],Lp[5],Lpp[5]) # l4
        if wig3s==0: return 0.
        wig3s *= tj0(L[6],Lp[6],Lpp[6]) # l5
        if wig3s==0: return 0.
    wig9s = np.float64(wigner_9j(L[0],L[1],L[2],Lp[0],Lp[1],Lp[2],Lpp[0],Lpp[1],Lpp[2]))
    if wig9s==0: return 0.
    wig9s *= np.float64(wigner_9j(L[2],L[3],L[4],Lp[2],Lp[3],Lp[4],Lpp[2],Lpp[3],Lpp[4]))
    if wig9s==0: return 0.
    wig9s *= np.float64(wigner_9j(L[4],L[5],L[6],Lp[4],Lp[5],Lp[6],Lpp[4],Lpp[5],Lpp[6]))
    if wig9s==0: return 0.
    pref = C_ell(L)*C_ell(Lp)*C_ell(Lpp)/(4.*np.pi)**2.5
    return pref*wig3s*wig9s

# %%
def load_integrals(lH1,lH2,lH3,lH4,bH1,bH2,bH3,bH4,L1,L2,L3,L4,L5,L5p,phiH,tjs=np.inf):
    if tjs==np.inf:
        pref = tj0(L1,L2,L5)*tj0(L3,L4,L5p)
        if pref==0: return 0.
    else:
        pref = tjs
    pref *= (4.*np.pi)*phiH*np.sqrt(2.)*(1.0j)**(L1+L2+L3+L4-L5+L5p) # adding (4pi)^4 prefactor from angular coupling
    pref *= C_ell([L1,L2,L3,L4,L5,L5p])
    pref *= (-1.)**(lH1+lH2+lH3+lH4)

    integ = (Pk1_arr[L1][lH1][bH1]*Pk2_arr[L2][lH2][bH2])[:,None]*(Pk3_arr[L3][lH3][bH3]*Pk4_arr[L4][lH4][bH4])[None,:]*Ps_arr[L5][L5p]
    out = pref*simps(simps(integ*x2,x_arr[:,None],axis=0)*x2p,xp_arr)
    return out

# %%
def kernel(L1,L2,L3,L4,L5,L5p,lH1,lH2,lH12,lH3,lH4,bH1,bH2,bH3,bH4):
    
    # First contract {L1,L2,(L5),0,(L5),0,L5} and {0,0,(0),L3,(L3),L4,L5p} contributions
    def contract5(L,Lp,L5zero=False):
        """Contract P_Lambda and P_Lambda'. Returns a list of Lambda' and the weights.
        Note that we compute the Wigner-3j symbols as early as possible to skip computing zeros.
        
        If L5zero = True, we skip any multiplets with L5'' \neq 0, since these are not needed later.
        """
        ells = []
        weights = []
        for Lpp1 in range(abs(L[0]-Lp[0]),min([LMAX,L[0]+Lp[0]])+1):
            wig1 = tj0(L[0],Lp[0],Lpp1)
            if wig1==0: continue
            for Lpp2 in range(abs(L[1]-Lp[1]),min([LMAX,L[1]+Lp[1]])+1):
                wig2 = tj0(L[1],Lp[1],Lpp2)
                if wig2==0: continue
                for Lpp12 in range(abs(Lpp1-Lpp2),min([LMAX,Lpp1+Lpp2])+1):
                    for Lpp3 in range(abs(L[3]-Lp[3]),min([LMAX,L[3]+Lp[3]])+1):
                        wig3 = tj0(L[3],Lp[3],Lpp3)
                        if wig3==0: continue
                        for Lpp123 in range(abs(Lpp12-Lpp3),min([LMAX,Lpp12+Lpp3])+1):
                            for Lpp4 in range(abs(L[5]-Lp[5]),min([LMAX,L[5]+Lp[5]])+1):
                                wig4 = tj0(L[5],Lp[5],Lpp4)
                                if wig4==0: continue
                                for Lpp5 in range(abs(L[6]-Lp[6]),min([LMAX,L[6]+Lp[6]])+1):
                                    if L5zero==True and Lpp5>0: continue
                                    
                                    wig5 = tj0(L[6],Lp[6],Lpp5)
                                    if wig5==0: continue
                                        
                                    # Compute Gaunt coefficient
                                    gaunt = (-1.)**(Lpp1+Lpp2+Lpp3+Lpp4+Lpp5)*Gaunt5(L,Lp,[Lpp1,Lpp2,Lpp12,Lpp3,Lpp123,Lpp4,Lpp5],wigs=[wig1,wig2,wig3,wig4,wig5])
                                    if gaunt==0: continue
                                    
                                    ells.append([Lpp1,Lpp2,Lpp12,Lpp3,Lpp123,Lpp4,Lpp5])
                                    weights.append(gaunt)
        
        return np.asarray(ells),np.asarray(weights)

    first_contract = contract5([L1,L2,L5,0,L5,0,L5],[0,0,0,L3,L3,L4,L5p])
    if len(first_contract[0])==0: return 0.
    
    # Now contract these outputs with {lambda1,0,lambda1,lambda2,lambda3,0,lambda3} parts
    lam1s = [1,2,2,1]
    lam2s = [1,2,1,2]
    lam3s = [1,1,2,2]
    lamWs = [1.,1./np.sqrt(5.),1./np.sqrt(5.),-1./np.sqrt(5.)]

    # NB: we only allow for contributions from bins with L''_5 = 0, since this is required to couple with next contractions
    
    s_ell, s_weight = [],[]
    for j in range(len(first_contract[0])):
        first_ells = first_contract[0][j]
        first_w = first_contract[1][j]
        for i in range(len(lamWs)):
            tmp_ells,tmp_weights = contract5([lam1s[i],0,lam1s[i],lam2s[i],lam3s[i],0,lam3s[i]],first_ells,L5zero=True)
            tmp_weights *= lamWs[i]*first_w
            
            if len(tmp_ells)==0: continue
            
            s_ell += list(tmp_ells)
            s_weight += list(tmp_weights)
    
    if len(s_ell)==0: return 0.
    
    # Combine identical elements
    s_ell = np.ascontiguousarray(s_ell)
    order = np.lexsort(s_ell.T)
    diff = np.diff(s_ell[order], axis=0)
    uniq_mask = np.append(True, (diff != 0).any(axis=1))

    uniq_inds = order[uniq_mask]
    inv_idx = np.zeros_like(order)
    inv_idx[order] = np.cumsum(uniq_mask) - 1

    s_weight = np.bincount(inv_idx, weights=s_weight)
    s_ell = s_ell[uniq_inds]
    
    second_contract = [np.asarray(s_ell),np.asarray(s_weight)]
    
    # Now perform Gaunt integral over the new P_Lambda functions with the P_j and P_ell functions and sum the weights
    sum_contrib = 0.
    for k in range(len(second_contract[0])):
        LL1,LL2,LL12,LL3,_,LL4,_ = second_contract[0][k]
        second_w = second_contract[1][k]

        ### Iterate over j
        for j1 in [0,2]:
            wig1 = tj0(LL1,j1,lH1)
            if wig1==0: continue
            for j2 in [0,2]:
                wig2 = tj0(LL2,j2,lH2)
                if wig2==0: continue
                for j12 in [0,2]:
                    tja = tj0(j1,j2,j12)
                    if tja==0: continue
                    for j3 in [0,2]:
                        wig3 = tj0(LL3,j3,lH3)
                        if wig3==0: continue
                        for j4 in [0,2]:
                            tjb = tj0(j12,j3,j4)
                            if tjb==0: continue
                            wig4 = tj0(LL4,j4,lH4)
                            if wig4==0: continue
                             
                            contrib = tja*tjb*Z_ell(j1)*Z_ell(j2)*Z_ell(j3)*Z_ell(j4)*C_ell([j1,j2,j12,j3,j4])
                            
                            # Compute coupling using N=4 symbol for speed
                            coupling = Gaunt4([LL1,LL2,LL12,LL3,LL4],[j1,j2,j12,j3,j4],[lH1,lH2,lH12,lH3,lH4],wigs=[wig1,wig2,wig3,wig4])/np.sqrt(4.*np.pi)
                            
                            if coupling==0: continue
                            sum_contrib += coupling*contrib*second_w
                        
    return sum_contrib

# %%
print('NB: probably want to do ell and bin loops inside here!!')

sum_output = 0.

# Sum over all Ls
for L1 in range(LMAX+1):
    for L2 in range(LMAX+1):
        for L5 in range(abs(L1-L2),min([LMAX,L1+L2])+1):
            tj125 = tj0(L1,L2,L5)
            if tj125==0: continue
            for L3 in range(LMAX+1):
                for L4 in range(LMAX+1):
                    for L5p in range(abs(L3-L4),min([LMAX,L3+L4])+1):
                        tj345p = tj0(L3,L4,L5p)
                        if tj345p==0: continue
                        
                        # Load in the integrals
                        integ = load_integrals(lH1,lH2,lH3,lH4,bH1,bH2,bH3,bH4,L1,L2,L3,L4,L5,L5p,phiH,tjs=tj125*tj345p)
                        if integ==0: continue
                        
                        kk = kernel(L1,L2,L3,L4,L5,L5p,lH1,lH2,lH12,lH3,lH4,bH1,bH2,bH3,bH4)
                        #print(L1,L2,L3,L4,L5,L5p,kk,integ)
                        if kk!=0:
                            print("[%d%d%d%d%d%d]: %.3e"%(L1,L2,L3,L4,L5,L5p,c*kk))
                        
                        sum_output += kk*c
# Out:
# NB: probably want to do ell and bin loops inside here!!
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: ComplexWarning: Casting complex values to real discards the imaginary part
# [010111]: -3.793e-30
# [010313]: 1.599e-31
# [011110]: -1.047e-29
# [011112]: -5.027e-24
# [011312]: 1.197e-31
# [012111]: 6.515e-26
# [012113]: 8.457e-26
# [012311]: -7.386e-34
# [012313]: -4.432e-33
# [013112]: 2.234e-31
# [013310]: -5.308e-32
# [013312]: -1.268e-32
# [014113]: -1.126e-32
# [014311]: 3.290e-34
# [014313]: 6.614e-34
# [030131]: -1.428e-33
# [030333]: 2.599e-38
# [031132]: 1.309e-33
# [031332]: -3.794e-34
# [031334]: -4.437e-34
# [032131]: 2.600e-35
# [032133]: 1.841e-35
# [032331]: 3.845e-36
# [032333]: 1.350e-36
# [033132]: 4.982e-34
# [033134]: -9.095e-34
# [033332]: 2.618e-38
# [033334]: 2.860e-38
# [034133]: 2.592e-36
# [034331]: -5.198e-40
# [034333]: -1.423e-40
# [110101]: -3.655e-30
# [111102]: 2.068e-32
# [111302]: -4.631e-36
# [112101]: -2.068e-32
# [112301]: -1.985e-36
# [113102]: 1.329e-33
# [113302]: -3.580e-37
# [114301]: -2.947e-37
# [110121]: -9.348e-32
# [110323]: 3.641e-33
# [111120]: -1.303e-26
# [111122]: -7.652e-27
# [111322]: 4.614e-34
# [111324]: -8.386e-35
# [112121]: -4.944e-27
# [112123]: 1.057e-26
# [112321]: -3.929e-35
# [112323]: -1.966e-34
# [113122]: 9.016e-34
# [113124]: -7.749e-35
# [113320]: -1.610e-34
# [113322]: -7.390e-35
# [113324]: 6.967e-36
# [114123]: -5.966e-34
# [114321]: 6.885e-35
# [114323]: 3.371e-35
# [130121]: 7.876e-34
# [130323]: -7.110e-38
# [131120]: 3.905e-33
# [131122]: 2.225e-33
# [131322]: 5.301e-36
# [131324]: 1.212e-35
# [132121]: 1.457e-33
# [132123]: -3.182e-33
# [132321]: 8.093e-36
# [132323]: 8.088e-36
# [133122]: -1.449e-36
# [133124]: 5.549e-36
# [133320]: -1.675e-40
# [133322]: 2.543e-40
# [133324]: -5.978e-40
# [134123]: 2.151e-36
# [134321]: -3.157e-40
# [134323]: -7.681e-40
# [130343]: -6.156e-39
# [131142]: 4.597e-36
# [131342]: -6.785e-37
# [131344]: -2.243e-36
# [132143]: -2.457e-36
# [132343]: 1.257e-36
# [133142]: -1.848e-37
# [133144]: -1.993e-36
# [133342]: 1.262e-40
# [133344]: 2.101e-40
# [134143]: -4.895e-36
# [134343]: -1.720e-40
# [210111]: -2.491e-31
# [210313]: 1.011e-32
# [211110]: -6.877e-31
# [211112]: -3.179e-25
# [211312]: 7.568e-33
# [212111]: 4.120e-27
# [212113]: 5.349e-27
# [212311]: -4.672e-35
# [212313]: -2.803e-34
# [213112]: 1.468e-32
# [213310]: -3.357e-33
# [213312]: -8.019e-34
# [214113]: -7.396e-34
# [214311]: 2.081e-35
# [214313]: 4.184e-35
# [210131]: -2.832e-34
# [210333]: -9.937e-39
# [211132]: 2.596e-34
# [211332]: -4.573e-35
# [211334]: -5.346e-35
# [212131]: 1.427e-36
# [212133]: -2.776e-36
# [212331]: 4.635e-37
# [212333]: 1.629e-37
# [213132]: 3.165e-35
# [213134]: -7.202e-35
# [213332]: 1.091e-39
# [213334]: 3.069e-39
# [214133]: -1.440e-37
# [214331]: -1.159e-42
# [214333]: -5.130e-42
# [230111]: -2.115e-33
# [230313]: -2.446e-37
# [231110]: -5.837e-33
# [231112]: -1.370e-31
# [231312]: -1.831e-37
# [232111]: 1.816e-33
# [232113]: 2.325e-33
# [232311]: -1.828e-39
# [232313]: 6.519e-40
# [233112]: 1.246e-34
# [233310]: -4.915e-39
# [233312]: -2.463e-38
# [234113]: -6.278e-36
# [234311]: 7.046e-40
# [234313]: 1.024e-39
# [230131]: -2.176e-34
# [230333]: -1.058e-38
# [231132]: 1.995e-34
# [231332]: -2.938e-35
# [231334]: -3.434e-35
# [232131]: 3.674e-37
# [232133]: -3.388e-36
# [232331]: 2.977e-37
# [232333]: 1.047e-37
# [233132]: 1.120e-35
# [233134]: -3.417e-35
# [233332]: 3.771e-41
# [233334]: 1.850e-39
# [234133]: -2.392e-37
# [234331]: 1.902e-41
# [234333]: 5.680e-43
# [310121]: -1.930e-32
# [310323]: 8.341e-34
# [311120]: -2.985e-27
# [311122]: -1.753e-27
# [311322]: 1.057e-34
# [311324]: -1.921e-35
# [312121]: -1.133e-27
# [312123]: 2.422e-27
# [312321]: -8.997e-36
# [312323]: -4.503e-35
# [313122]: 2.118e-34
# [313124]: -2.039e-35
# [313320]: -3.688e-35
# [313322]: -1.693e-35
# [313324]: 1.596e-36
# [314123]: -1.430e-34
# [314321]: 1.577e-35
# [314323]: 7.722e-36
# [310343]: -8.668e-39
# [311142]: 6.449e-36
# [311342]: -3.771e-37
# [311344]: -1.245e-36
# [312143]: -3.447e-36
# [312343]: 6.984e-37
# [313142]: 1.199e-37
# [313144]: -8.374e-37
# [313342]: 5.387e-41
# [313344]: 7.713e-41
# [314143]: -9.661e-37
# [314343]: -4.278e-41
# [330101]: 1.883e-31
# [331102]: -1.065e-33
# [331302]: 2.387e-37
# [332101]: 1.065e-33
# [332301]: 1.023e-37
# [333102]: -6.848e-35
# [333302]: 1.845e-38
# [334301]: 1.519e-38
# [330121]: 8.008e-34
# [330323]: -4.858e-38
# [331120]: -4.340e-34
# [331122]: -2.416e-34
# [331322]: 1.459e-36
# [331324]: 3.338e-36
# [332121]: -1.249e-34
# [332123]: 3.026e-34
# [332321]: 2.229e-36
# [332323]: 2.228e-36
# [333122]: 1.048e-36
# [333124]: 8.016e-37
# [333320]: -3.452e-40
# [333322]: -1.589e-40
# [333324]: -9.257e-41
# [334123]: -1.138e-36
# [334321]: 1.402e-40
# [334323]: 8.470e-41
# [330343]: -5.156e-39
# [331142]: 3.835e-36
# [331342]: -1.948e-37
# [331344]: -6.433e-37
# [332143]: -2.050e-36
# [332343]: 3.608e-37
# [333142]: 9.074e-38
# [333144]: -3.977e-37
# [333342]: 2.572e-41
# [333344]: 3.473e-41
# [334143]: -2.724e-37
# [334343]: -1.528e-41
# [410131]: 3.796e-35
# [410333]: 1.284e-38
# [411132]: -3.480e-35
# [411332]: -1.638e-35
# [411334]: -1.917e-35
# [412131]: 2.654e-36
# [412133]: 5.272e-36
# [412331]: 1.660e-37
# [412333]: 5.818e-38
# [413132]: 4.697e-35
# [413134]: -7.299e-35
# [413332]: 2.981e-39
# [413334]: 1.574e-39
# [414133]: 5.211e-37
# [414331]: -7.757e-41
# [414333]: -1.692e-41
# [430111]: 1.304e-36
# [430313]: 1.589e-39
# [431110]: 3.599e-36
# [431112]: -5.077e-32
# [431312]: 1.189e-39
# [432111]: 6.579e-34
# [432113]: 8.541e-34
# [432311]: -7.340e-42
# [432313]: -4.404e-41
# [433112]: -7.680e-38
# [433310]: -5.275e-40
# [433312]: -1.260e-40
# [434113]: 3.870e-39
# [434311]: 3.270e-42
# [434313]: 6.573e-42
# [430131]: 6.101e-38
# [430333]: 1.789e-42
# [431132]: -5.592e-38
# [431332]: 1.054e-38
# [431334]: 1.233e-38
# [432131]: -3.944e-40
# [432133]: 4.480e-40
# [432331]: -1.068e-40
# [432333]: -3.754e-41
# [433132]: -8.387e-39
# [433134]: 1.805e-38
# [433332]: -3.309e-43
# [433334]: -7.220e-43
# [434133]: 1.565e-41
# [434331]: 2.629e-45
# [434333]: 1.644e-45
